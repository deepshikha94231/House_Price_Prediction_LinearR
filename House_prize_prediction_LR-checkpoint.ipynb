# %% [markdown]
# # About data:
#
#
#
# ## This data frame contains the following columns:
# #### date: Date of the home sale
# #### price: Price of each home sold
# #### bedrooms: Number of bedrooms
# #### bathrooms: Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# #### sqft_living: Square footage of the apartments interior living space
# #### sqft_lot: Square footage of the land space
# #### floors: Number of floors
# #### waterfront: A dummy variable for whether the apartment was overlooking the waterfront or not
# #### view: An index from 0 to 4 of how good the view of the property was
# #### condition: An index from 1 to 5 on the condition of the apartment,
# #### sqft_above: The square footage of the interior housing space that is above ground level
# #### sqft_basement: The square footage of the interior housing space that is below ground level
# #### yr_built: The year the house was initially built
# #### yr_renovated: The year of the house’s last renovation
# #### street: Street where house is located
# #### city: City where house is located
# #### statezip: What zipcode area the house is in
# #### country:  In which country house is located

# %% [markdown]
# ## 1. Import Data

# %%
import pandas as pd

# %%
data = pd.read_csv('house_data.csv')
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00  313000.00      3.00       1.50         1340      7912
# 1  2014-05-02 00:00:00 2384000.00      5.00       2.50         3650      9050
# 2  2014-05-02 00:00:00  342000.00      3.00       2.00         1930     11947
# 3  2014-05-02 00:00:00  420000.00      3.00       2.25         2000      8030
# 4  2014-05-02 00:00:00  550000.00      4.00       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0    1.50           0     0          3        1340              0      1955
# 1    2.00           0     4          5        3370            280      1921
# 2    1.00           0     0          4        1930              0      1966
# 3    1.00           0     0          4        1000           1000      1963
# 4    1.00           0     0          4        1140            800      1976
#
# ...

# %%
pd.set_option("display.max_column",None)

# %%
data["country"].value_counts()
# Out:
# country
# USA    4600
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Check dataset size

# %%
data.shape
# Out:
# (4600, 18)

# %% [markdown]
# ## 3. Find and treat missing values (If any)

# %%
data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, street, city, statezip, country]
# Index: []

# %% [markdown]
# ## 4. Column types and describe which columns are numerical, or categorical

# %%
data.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# price                   float64
# bedrooms                float64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# street                   object
# city                     object
# statezip                 object
# country                  object
# dtype: object

# %%
data[data["bedrooms"]==0]
# Out:
#            date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 2365 2014-06-12 1095000.00      0.00       0.00         3064      4764
# 3209 2014-06-24 1295648.00      0.00       0.00         4810     28008
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 2365    3.50           0     2          3        3064              0
# 3209    2.00           0     0          3        4810              0
#
#       yr_built  yr_renovated            street     city  statezip country
# 2365      1990          2009     814 E Howe St  Seattle  WA 98102     USA
# 3209      1990          2009  20418 NE 64th Pl  Redmond  WA 98053     USA

# %%
data.drop(data[data["bedrooms"] == 0].index, inplace=True)

# %%
data.shape
# Out:
# (4598, 18)

# %%
data[data["bathrooms"]==0]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, street, city, statezip, country]
# Index: []

# %% [markdown]
# ## 5. Perform Univariate analysis
#
# ### i. Calculate mean, median, std dev, and quartiles of numerical data

# %%
# converting the scientific notation to the normal notation
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
data.describe()
# Out:
#                                 date       price  bedrooms  bathrooms  \
# count                           4598     4598.00   4598.00    4598.00
# mean   2014-06-07 03:07:54.467159552   551683.14      3.40       2.16
# min              2014-05-02 00:00:00        0.00      1.00       0.75
# 25%              2014-05-21 00:00:00   322625.00      3.00       1.75
# 50%              2014-06-09 00:00:00   460443.46      3.00       2.25
# 75%              2014-06-24 00:00:00   653750.00      4.00       2.50
# max              2014-07-10 00:00:00 26590000.00      9.00       8.00
# std                              NaN   563793.71      0.91       0.78
#
#        sqft_living   sqft_lot  floors  waterfront    view  condition  \
# count      4598.00    4598.00 4598.00     4598.00 4598.00    4598.00
# mean       2138.57   14851.85    1.51        0.01    0.24       3.45
# min         370.00     638.00    1.00        0.00    0.00       1.00
# ...

# %% [markdown]
# ### ii. The distribution of numerical variables.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num=['price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement', 
     'yr_built', 'yr_renovated']

for col in num:
    plt.figure()
    sns.distplot(data[col], bins=20, kde=True)
    plt.xlabel(col)
    plt.ylabel('Density')
    plt.title(f'Distribution Plot of {col}')
    plt.show()
# Out:
# C:\Users\deep9\AppData\Local\Temp\ipykernel_9944\3501044407.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[col], bins=20, kde=True)
# C:\Users\deep9\AppData\Local\Temp\ipykernel_9944\3501044407.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
data.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %% [markdown]
# ## 6. Perform Bivariate analysis

# %% [markdown]
# ### i. Plot pair plots

# %%
# Select the numerical variables for pair plot
num_var = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement']

# Create pair plots
sns.pairplot(data[num_var])
plt.show()
# Out:
# C:\Users\deep9\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### ii. Calculate Pearson correlation, and plot their heatmap

# %%
import numpy as np
num = data.select_dtypes(include=[np.number])
corr = num.corr()

# %%
k = num.corr()

# %%
corr_matrix = num.corr()

# Create a mask to hide the upper triangle (including the diagonal) of the correlation matrix
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

plt.figure(figsize=(20, 15))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', mask=mask)
plt.title("Correlation Heatmap (Lower Triangle)")
plt.show()

# %% [markdown]
# ## 7. Model: Linear Regression

# %%
data.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression, Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
X = data.drop(columns=['date', 'price','bedrooms', 'bathrooms', 'floors', 'street', 'city', 'statezip', 'country'], axis = 1)
y = data['price']
X.dtypes
# Out:
# sqft_living      int64
# sqft_lot         int64
# waterfront       int64
# view             int64
# condition        int64
# sqft_above       int64
# sqft_basement    int64
# yr_built         int64
# yr_renovated     int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=0)

# %%
lasso = Lasso(alpha = 1.0)

# %%
lasso.fit(X_train, y_train)
# Out:
# C:\Users\deep9\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.069e+14, tolerance: 1.354e+11
#   model = cd_fast.enet_coordinate_descent(
# Lasso()

# %%
lasso.score(X_test, y_test), lasso.score(X_train, y_train)
# Out:
# (0.5109134961362841, 0.1855272875401197)

# %%
lasso.coef_
# Out:
# array([ 2.70010555e+02, -7.20518257e-01,  3.69162989e+05,  5.33161328e+04,
#         2.55628408e+04, -1.74688903e+00, -4.43260752e+01, -1.76157547e+03,
#         7.32693458e-01])

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
predicted_y=model.predict(x_train)

# %%
print(model.intercept_)
print(model.coef_)
lr_regression= model.coef_*x_train + model.intercept_
print("The equation of the fitted regression line is:")
print("Coefficients:", model.coef_, ";  Intercept", model.intercept_)
# Out:
# -15513.366219993914
# [ 2.46001974e+04  6.62632463e+15 -6.62632463e+15 -6.62632463e+15]
# The equation of the fitted regression line is:
# Coefficients: [ 2.46001974e+04  6.62632463e+15 -6.62632463e+15 -6.62632463e+15] ;  Intercept -15513.366219993914

# %%
y_pred= model.predict(x_test)
print("The predicted values of price based on testing dataset is: ", y_pred)
# Out:
# The predicted values of price based on testing dataset is:  [ 251750.63378001  832358.63378001  539494.63378001  676710.63378001
#   367462.63378001  562022.63378001  591718.63378001  725862.63378001
#   466790.63378001  820070.63378001  432998.63378001  314214.63378001
#   846694.63378001  209766.63378001  914278.63378001  512870.63378001
#  1114982.63378001  766822.63378001  315238.63378001  453478.63378001
#   215910.63378001  721766.63378001  875366.63378001  547686.63378001
#   429926.63378001  754534.63378001  490342.63378001 1180518.63378001
#   254822.63378001  650086.63378001  495462.63378001  441190.63378001
#   836454.63378001  670566.63378001  824166.63378001  404326.63378001
#   355174.63378001  381798.63378001  779110.63378001  639846.63378001
#   568166.63378001  247654.63378001 1141606.63378001  572262.63378001
#   444262.63378001  598886.63378001  803686.63378001  588646.63378001
#   341862.63378001  768870.63378001  461670.63378001  897894.63378001
# ...

# %%
df= pd.DataFrame({"Actual": y_test, "Predicted": y_pred})
df
# Out:
#         Actual  Predicted
# 3128 326000.00  251750.63
# 3551 750000.00  832358.63
# 896  565000.00  539494.63
# 1977 749000.00  676710.63
# 3459 495000.00  367462.63
# ...        ...        ...
# 1220 782000.00  609126.63
# 1721 320000.00  822118.63
# 1141 180000.00  213862.63
# 36   440000.00  197478.63
# 706  592500.00  574310.63
#
# [920 rows x 2 columns]

# %%
k = df.head(15)
k
# Out:
#         Actual  Predicted
# 3128 326000.00  251750.63
# 3551 750000.00  832358.63
# 896  565000.00  539494.63
# 1977 749000.00  676710.63
# 3459 495000.00  367462.63
# 348  350000.00  562022.63
# 302  409500.00  591718.63
# 3252 599000.00  725862.63
# 3236 343500.00  466790.63
# 2889 925000.00  820070.63
# 500  770000.00  432998.63
# 559  523000.00  314214.63
# 2033 435000.00  846694.63
# 4117 165000.00  209766.63
# 189  860000.00  914278.63

# %%
k.plot(kind="bar", color=("g","r"))
plt.xlabel("Index")
plt.ylabel("Price")
plt.title("Comparison between actual and predicted values of price")
plt.show()

# %%
from sklearn import metrics  
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test, y_pred)) 
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R-2:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 179646.6810431866
# Mean Squared Error: 66577107112.039536
# Root Mean Squared Error: 258025.40012959874
# R-2: 0.4277688361148594

# %% [markdown]
# ## The End
# Thank for reading my analysis
